# %%
print("Name:Jaimin Khilwani")
print("Favoraite App:Instagram")
# Out:
# Name:Jaimin Khilwani
# Favoraite App:Instagram

# %%
print("Welcome to Data Scinence with Python")
# Out:
# Welcome to Data Scinence with Python
